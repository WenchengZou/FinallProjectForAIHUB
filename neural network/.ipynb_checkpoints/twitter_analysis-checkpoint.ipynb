# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# %matplotlib inline

# %%
# load our data from csv and split into x_train and y_train
x_train = pd.read_csv('../Dataset/twitter.csv')
x_train = x_train[['neurate','posrate','negrate']]
x_train = x_train.values
print(x_train.shape)
y_train = pd.read_csv('../Dataset/twitter.csv')
y_train = y_train[['increaserange']]
y_train = y_train.values
y_train = y_train.reshape(25,)
print(y_train)
# Out:
# (25, 3)
# [3 2 2 1 2 3 4 4 3 2 1 2 3 4 4 3 2 1 1 3 3 3 2 0 0]

# %%
# define NN, apply softmax for output layer (multi-classification)
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dense(5, activation='softmax')
])

# use sparse categorical crossentropy can avoid use onehot encoding.
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
# use adam for gradient descent
optimizer = tf.keras.optimizers.Adam()
# compile model with configurations above
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])
# fit our model with epochs of 50 (too hard to get reliable data...) 
history = model.fit(x_train,y_train,epochs=50,batch_size=2)
print(history.history.keys())
plt.plot(history.history['loss'])
plt.title('Loss')
plt.savefig('loss.png')

#model.save('twitter_analysis.h5')

model.summary()
result = model.predict(x_train)
# this will print a 5-column list, and each colunm is the probability that this input belongs to.
print(result[19])
# take a look for a classification result (class number reference is in README)
for i in range(19,20):
    k = np.argmax(result[i])
    print("This should be classified in to class ",k+1)
# Out:
# Epoch 1/50
# 13/13 [==============================] - 0s 846us/step - loss: 1.5806 - accuracy: 0.3200
# Epoch 2/50
# 13/13 [==============================] - 0s 845us/step - loss: 1.5646 - accuracy: 0.3200
# Epoch 3/50
# 13/13 [==============================] - 0s 909us/step - loss: 1.5578 - accuracy: 0.3200
# Epoch 4/50
# 13/13 [==============================] - 0s 892us/step - loss: 1.5506 - accuracy: 0.3200
# Epoch 5/50
# 13/13 [==============================] - 0s 875us/step - loss: 1.5493 - accuracy: 0.3200
# Epoch 6/50
# 13/13 [==============================] - 0s 868us/step - loss: 1.5414 - accuracy: 0.3200
# Epoch 7/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5375 - accuracy: 0.3200
# Epoch 8/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5328 - accuracy: 0.3200
# Epoch 9/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5321 - accuracy: 0.3200
# Epoch 10/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5281 - accuracy: 0.3200
# Epoch 11/50
# 13/13 [==============================] - 0s 902us/step - loss: 1.5280 - accuracy: 0.3200
# Epoch 12/50
# 13/13 [==============================] - 0s 864us/step - loss: 1.5258 - accuracy: 0.3200
# Epoch 13/50
# 13/13 [==============================] - 0s 930us/step - loss: 1.5238 - accuracy: 0.3200
# Epoch 14/50
# 13/13 [==============================] - 0s 931us/step - loss: 1.5197 - accuracy: 0.3200
# Epoch 15/50
# 13/13 [==============================] - 0s 994us/step - loss: 1.5199 - accuracy: 0.3200
# Epoch 16/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5169 - accuracy: 0.3200
# Epoch 17/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5156 - accuracy: 0.3200
# Epoch 18/50
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5158 - accuracy: 0.3200
# Epoch 19/50
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5137 - accuracy: 0.3200
# Epoch 20/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5141 - accuracy: 0.3200
# Epoch 21/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5124 - accuracy: 0.3200
# Epoch 22/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5131 - accuracy: 0.3200
# Epoch 23/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5124 - accuracy: 0.3200
# Epoch 24/50
# 13/13 [==============================] - ETA: 0s - loss: 1.5524 - accuracy: 0.0000e+ - 0s 1ms/step - loss: 1.5117 - accuracy: 0.3200
# Epoch 25/50
# 13/13 [==============================] - 0s 2ms/step - loss: 1.5113 - accuracy: 0.3200
# Epoch 26/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5131 - accuracy: 0.3200
# Epoch 27/50
# 13/13 [==============================] - 0s 996us/step - loss: 1.5103 - accuracy: 0.3200
# Epoch 28/50
# 13/13 [==============================] - 0s 950us/step - loss: 1.5116 - accuracy: 0.3200
# Epoch 29/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5131 - accuracy: 0.3200
# Epoch 30/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5102 - accuracy: 0.3200
# Epoch 31/50
# 13/13 [==============================] - 0s 983us/step - loss: 1.5121 - accuracy: 0.3200
# Epoch 32/50
# 13/13 [==============================] - 0s 879us/step - loss: 1.5090 - accuracy: 0.3200
# Epoch 33/50
# 13/13 [==============================] - 0s 906us/step - loss: 1.5110 - accuracy: 0.3200
# Epoch 34/50
# 13/13 [==============================] - 0s 944us/step - loss: 1.5102 - accuracy: 0.3200
# Epoch 35/50
# 13/13 [==============================] - 0s 875us/step - loss: 1.5082 - accuracy: 0.3200
# Epoch 36/50
# 13/13 [==============================] - 0s 918us/step - loss: 1.5104 - accuracy: 0.3200
# Epoch 37/50
# 13/13 [==============================] - 0s 984us/step - loss: 1.5083 - accuracy: 0.3200
# Epoch 38/50
# 13/13 [==============================] - 0s 910us/step - loss: 1.5098 - accuracy: 0.3200
# Epoch 39/50
# 13/13 [==============================] - 0s 858us/step - loss: 1.5078 - accuracy: 0.3200
# Epoch 40/50
# 13/13 [==============================] - 0s 844us/step - loss: 1.5088 - accuracy: 0.3200
# Epoch 41/50
# 13/13 [==============================] - 0s 834us/step - loss: 1.5078 - accuracy: 0.3200
# Epoch 42/50
# 13/13 [==============================] - 0s 879us/step - loss: 1.5085 - accuracy: 0.3200
# Epoch 43/50
# 13/13 [==============================] - 0s 943us/step - loss: 1.5081 - accuracy: 0.3200
# Epoch 44/50
# 13/13 [==============================] - 0s 931us/step - loss: 1.5083 - accuracy: 0.3200
# Epoch 45/50
# 13/13 [==============================] - 0s 968us/step - loss: 1.5069 - accuracy: 0.3200
# Epoch 46/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5082 - accuracy: 0.3200
# Epoch 47/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5073 - accuracy: 0.3200
# Epoch 48/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5078 - accuracy: 0.3200
# Epoch 49/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5068 - accuracy: 0.3200
# Epoch 50/50
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5070 - accuracy: 0.3200
# dict_keys(['loss', 'accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  128
# _________________________________________________________________
# dense_1 (Dense)              multiple                  528
# _________________________________________________________________
# dense_2 (Dense)              multiple                  85
# =================================================================
# Total params: 741
# Trainable params: 741
# Non-trainable params: 0
# _________________________________________________________________
# [0.0865962  0.15770583 0.27792913 0.31633455 0.1614343 ]
# This should be classified in to class  4
